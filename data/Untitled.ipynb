# %%
import pandas as pd

df = pd.read_csv("kills_2021.csv", nrows=100000, encoding="latin1")
df.to_csv("kills_2021.csv", index=False)

print("Done.")
# Out:
# Done.

# %%
import pandas as pd

df = pd.read_csv("kills_2022.csv", nrows=100000, encoding="latin1")
df.to_csv("kills_2022.csv", index=False)

print("Done.")
# Out:
# Done.

# %%
import os
import pandas as pd

# ===== 配置区域 =====
FOLDER = "."           # 当前文件夹，如需指定其他路径可以改成 "./data"
THRESHOLD_MB = 25      # 大于多少 MB 才会被裁剪
MAX_ROWS = 80000       # 保留的行数
BACKUP_EXT = ".bak"    # 备份文件后缀

# 将 MB 转成字节
THRESHOLD_BYTES = THRESHOLD_MB * 1024 * 1024

# 常见编码尝试列表
ENCODINGS_TO_TRY = ["utf-8", "latin1", "ISO-8859-1", "cp1252"]

print(f"扫描文件夹: {os.path.abspath(FOLDER)}")
print(f"阈值: > {THRESHOLD_MB} MB 的 CSV 将被裁剪为前 {MAX_ROWS} 行\n")

for fname in os.listdir(FOLDER):
    fpath = os.path.join(FOLDER, fname)
    
    # 只处理普通文件 + .csv 后缀
    if not os.path.isfile(fpath):
        continue
    if not fname.lower().endswith(".csv"):
        continue

    size_bytes = os.path.getsize(fpath)
    size_mb = size_bytes / (1024 * 1024)

    if size_bytes <= THRESHOLD_BYTES:
        print(f"[跳过] {fname}  ({size_mb:.2f} MB ≤ {THRESHOLD_MB} MB)")
        continue

    print(f"\n[处理] {fname}  ({size_mb:.2f} MB > {THRESHOLD_MB} MB)")
    df = None
    used_encoding = None

    # 尝试不同编码读取前 MAX_ROWS 行
    for enc in ENCODINGS_TO_TRY:
        try:
            print(f"  尝试编码: {enc} ...", end="")
            df = pd.read_csv(fpath, nrows=MAX_ROWS, encoding=enc)
            used_encoding = enc
            print(" 成功")
            break
        except Exception as e:
            print(f"  失败: {e}")

    if df is None:
        print(f"  ❌ 所有编码尝试失败，跳过该文件：{fname}")
        continue

    # 备份原文件
    backup_path = fpath + BACKUP_EXT
    if not os.path.exists(backup_path):
        os.replace(fpath, backup_path)
        print(f"  已备份原始文件为: {backup_path}")
    else:
        print(f"  警告: 备份文件已存在 ({backup_path})，将覆盖原文件而不再额外备份。")

    # 将裁剪后的数据写回原文件名
    df.to_csv(fpath, index=False)
    new_size_bytes = os.path.getsize(fpath)
    new_size_mb = new_size_bytes / (1024 * 1024)

    print(f"  使用编码: {used_encoding}")
    print(f"  ✅ 已写回裁剪后的文件: {fname}  (约 {new_size_mb:.2f} MB)")
    
print("\n全部处理完成 ✅")
# Out:
# 扫描文件夹: /Users/ha0s/Desktop/valorant-dashboard/public/data
# 阈值: > 25 MB 的 CSV 将被裁剪为前 80000 行
#
# [跳过] scores_2024.csv  (0.05 MB ≤ 25 MB)
# [跳过] maps_played_2022.csv  (0.91 MB ≤ 25 MB)
# [跳过] kills_2023.csv  (11.14 MB ≤ 25 MB)
#
# [处理] rounds_kills_2021.csv  (120.40 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./rounds_kills_2021.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: rounds_kills_2021.csv  (约 11.99 MB)
# [跳过] kills_2022.csv  (15.69 MB ≤ 25 MB)
# [跳过] maps_played_2023.csv  (0.07 MB ≤ 25 MB)
# [跳过] maps_scores_2021.csv  (2.08 MB ≤ 25 MB)
# [跳过] scores_2025.csv  (0.05 MB ≤ 25 MB)
# [跳过] win_loss_methods_round_number_2024.csv  (5.37 MB ≤ 25 MB)
# [跳过] agents_pick_rates_2024.csv  (1.77 MB ≤ 25 MB)
# [跳过] maps_played_2021.csv  (1.45 MB ≤ 25 MB)
# [跳过] maps_scores_2023.csv  (0.11 MB ≤ 25 MB)
# [跳过] team_mapping_2025.csv  (0.00 MB ≤ 25 MB)
#
# [处理] rounds_kills_2022.csv  (120.14 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./rounds_kills_2022.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: rounds_kills_2022.csv  (约 12.33 MB)
# [跳过] all_teams_ids.csv  (0.06 MB ≤ 25 MB)
# [跳过] rounds_kills_2023.csv  (9.71 MB ≤ 25 MB)
# [跳过] kills_2021.csv  (15.04 MB ≤ 25 MB)
# [跳过] team_mapping_2024.csv  (0.00 MB ≤ 25 MB)
# [跳过] maps_scores_2022.csv  (1.29 MB ≤ 25 MB)
# [跳过] agents_pick_rates_2025.csv  (1.88 MB ≤ 25 MB)
# [跳过] win_loss_methods_round_number_2025.csv  (5.63 MB ≤ 25 MB)
#
# [处理] win_loss_methods_round_number_2021.csv  (75.16 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./win_loss_methods_round_number_2021.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: win_loss_methods_round_number_2021.csv  (约 10.27 MB)
# [跳过] scores_2022.csv  (0.53 MB ≤ 25 MB)
# [跳过] agents_pick_rates_2021.csv  (16.28 MB ≤ 25 MB)
# [跳过] maps_played_2024.csv  (0.09 MB ≤ 25 MB)
# [跳过] kills_2025.csv  (12.70 MB ≤ 25 MB)
# [跳过] kills_2024.csv  (11.21 MB ≤ 25 MB)
# [跳过] maps_played_2025.csv  (0.10 MB ≤ 25 MB)
# [跳过] team_mapping_2021.csv  (0.04 MB ≤ 25 MB)
# [跳过] scores_2023.csv  (0.04 MB ≤ 25 MB)
#
# [处理] win_loss_methods_round_number_2022.csv  (47.37 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./win_loss_methods_round_number_2022.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: win_loss_methods_round_number_2022.csv  (约 10.54 MB)
# [跳过] agents_pick_rates_2022.csv  (11.38 MB ≤ 25 MB)
# [跳过] scores_2021.csv  (0.98 MB ≤ 25 MB)
# [跳过] team_mapping_2023.csv  (0.00 MB ≤ 25 MB)
# [跳过] maps_scores_2025.csv  (0.15 MB ≤ 25 MB)
# [跳过] rounds_kills_2024.csv  (9.64 MB ≤ 25 MB)
# [跳过] rounds_kills_2025.csv  (10.92 MB ≤ 25 MB)
# [跳过] maps_scores_2024.csv  (0.14 MB ≤ 25 MB)
# [跳过] team_mapping_2022.csv  (0.02 MB ≤ 25 MB)
# [跳过] agents_pick_rates_2023.csv  (1.32 MB ≤ 25 MB)
# [跳过] win_loss_methods_round_number_2023.csv  (4.20 MB ≤ 25 MB)
# [跳过] maps_stats_2022.csv  (0.48 MB ≤ 25 MB)
# [跳过] maps_stats_2023.csv  (0.06 MB ≤ 25 MB)
# [跳过] maps_stats_2021.csv  (0.68 MB ≤ 25 MB)
# [跳过] kills_stats_2025.csv  (1.61 MB ≤ 25 MB)
# [跳过] all_tournaments_stages_match_types_ids.csv  (0.27 MB ≤ 25 MB)
# [跳过] kills_stats_2024.csv  (1.43 MB ≤ 25 MB)
# [跳过] maps_stats_2024.csv  (0.07 MB ≤ 25 MB)
# [跳过] kills_stats_2021.csv  (18.09 MB ≤ 25 MB)
# [跳过] maps_stats_2025.csv  (0.07 MB ≤ 25 MB)
# [跳过] kills_stats_2023.csv  (1.42 MB ≤ 25 MB)
# [跳过] kills_stats_2022.csv  (18.43 MB ≤ 25 MB)
# [跳过] teams_picked_agents_2025.csv  (1.37 MB ≤ 25 MB)
# [跳过] overview_2024.csv  (6.81 MB ≤ 25 MB)
# [跳过] eco_rounds_2023.csv  (4.30 MB ≤ 25 MB)
# [跳过] all_players_ids.csv  (0.19 MB ≤ 25 MB)
#
# [处理] eco_rounds_2022.csv  (52.02 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./eco_rounds_2022.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: eco_rounds_2022.csv  (约 11.58 MB)
# [跳过] overview_2025.csv  (7.48 MB ≤ 25 MB)
# [跳过] teams_picked_agents_2024.csv  (1.32 MB ≤ 25 MB)
# [跳过] draft_phase_2024.csv  (0.26 MB ≤ 25 MB)
#
# [处理] eco_rounds_2021.csv  (52.15 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./eco_rounds_2021.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: eco_rounds_2021.csv  (约 11.31 MB)
# [跳过] draft_phase_2025.csv  (0.27 MB ≤ 25 MB)
# [跳过] all_matches_games_ids.csv  (3.28 MB ≤ 25 MB)
# [跳过] draft_phase_2021.csv  (0.39 MB ≤ 25 MB)
# [跳过] teams_picked_agents_2023.csv  (1.04 MB ≤ 25 MB)
#
# [处理] overview_2022.csv  (64.36 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./overview_2022.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: overview_2022.csv  (约 14.06 MB)
# [跳过] eco_rounds_2025.csv  (3.14 MB ≤ 25 MB)
# [跳过] eco_rounds_2024.csv  (4.31 MB ≤ 25 MB)
# [跳过] overview_2023.csv  (5.40 MB ≤ 25 MB)
# [跳过] teams_picked_agents_2022.csv  (13.02 MB ≤ 25 MB)
# [跳过] draft_phase_2022.csv  (0.85 MB ≤ 25 MB)
#
# [处理] overview_2021.csv  (97.92 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./overview_2021.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: overview_2021.csv  (约 14.60 MB)
# [跳过] draft_phase_2023.csv  (0.20 MB ≤ 25 MB)
# [跳过] teams_picked_agents_2021.csv  (21.91 MB ≤ 25 MB)
# [跳过] eco_stats_2021.csv  (15.88 MB ≤ 25 MB)
#
# [处理] players_stats_2021.csv  (31.28 MB > 25 MB)
#   尝试编码: utf-8 ... 成功
#   已备份原始文件为: ./players_stats_2021.csv.bak
#   使用编码: utf-8
#   ✅ 已写回裁剪后的文件: players_stats_2021.csv  (约 13.34 MB)
# [跳过] players_stats_2023.csv  (1.71 MB ≤ 25 MB)
# [跳过] win_loss_methods_count_2024.csv  (0.25 MB ≤ 25 MB)
# [跳过] eco_stats_2023.csv  (1.22 MB ≤ 25 MB)
# [跳过] eco_stats_2022.csv  (16.06 MB ≤ 25 MB)
# [跳过] win_loss_methods_count_2025.csv  (0.26 MB ≤ 25 MB)
# [跳过] players_stats_2022.csv  (20.81 MB ≤ 25 MB)
# [跳过] win_loss_methods_count_2021.csv  (3.68 MB ≤ 25 MB)
# [跳过] all_teams_mapping.csv  (0.05 MB ≤ 25 MB)
# [跳过] win_loss_methods_count_2022.csv  (2.29 MB ≤ 25 MB)
# [跳过] players_stats_2025.csv  (2.46 MB ≤ 25 MB)
# [跳过] eco_stats_2025.csv  (1.36 MB ≤ 25 MB)
# [跳过] eco_stats_2024.csv  (1.22 MB ≤ 25 MB)
# [跳过] players_stats_2024.csv  (2.18 MB ≤ 25 MB)
# [跳过] win_loss_methods_count_2023.csv  (0.19 MB ≤ 25 MB)
#
# 全部处理完成 ✅
